# %%
# import necessary libraries.
import os
import sqlalchemy
import json
from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import inspect, func, create_engine
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base

# %%
engine = create_engine("sqlite:///database_2019.sqlite")
session = Session(engine)
insp = inspect(engine)

# %%
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
# Save references to each table
db2019 = Base.classes.db_2019

# Creating route for the data calls
def data():

    # weather = request.form['weather']
    # env = request.form['env']
    weather = 'Fair'
    env = 'Bump'

#     if (weather != "") & (env != ""):
#         response = session.query(db2019).filter_by(db2019.Weather_Condition == weather & env >= 1)

#     elif (weather != ""):
#         response = session.query(db2019).filter_by(db2019.Weather_Condition == weather)

#     elif (env != ""):
#         response = session.query(db2019).filter_by(env >= 1)

#     else:
#         response = session.query(db2019).all()

#     return print(response)

    session.query(db2019.Weather_Condition).first()

# %%
data()
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-30-a28c71a07a91> in <module>
# ----> 1 data()
#
# <ipython-input-29-684ac647e58a> in data()
#      27 #     return print(response)
#      28
# ---> 29     session.query(db2019).all()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\query.py in all(self)
#    3231                 :ref:`faq_query_deduplicating`
#    3232         """
# -> 3233         return list(self)
#    3234
#    3235     @_generative(_no_clauseelement_condition)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\loading.py in instances(query, cursor, context)
#      79             if single_entity:
#      80                 proc = process[0]
# ---> 81                 rows = [proc(row) for row in fetch]
#      82             else:
#      83                 rows = [
#
# ...

# %%
insp.get_table_names()
# Out:
# ['db_2019']

# %%
insp.get_columns('db_2019')
# Out:
# [{'name': 'ID',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 1},
#  {'name': 'Severity',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Start_Time',
#   'type': TIMESTAMP(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'End_Time',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Start_Lat',
#   'type': REAL(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Start_Lng',
#   'type': REAL(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'City',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'State',
# ...
